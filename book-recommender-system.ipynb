# %%
import numpy as np
import pandas as pd

# %%
books = pd.read_csv("Books.csv")
users = pd.read_csv("Users.csv")
ratings = pd.read_csv("Ratings.csv")
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_8404\2906776592.py:1: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   books = pd.read_csv("Books.csv")

# %%
books.head(100)
# Out:
#           ISBN                                         Book-Title  \
# 0   0195153448                                Classical Mythology
# 1   0002005018                                       Clara Callan
# 2   0060973129                               Decision in Normandy
# 3   0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4   0393045218                             The Mummies of Urumchi
# ..         ...                                                ...
# 95  0671867156                          Pretend You Don't See Her
# 96  0312252617                                         Fast Women
# 97  0312261594                                Female Intelligence
# 98  0316748641      Pasquale's Nose: Idle Days in an Italian Town
# 99  0316973742                       The Gospel of Judas: A Novel
#
#              Book-Author Year-Of-Publication                   Publisher  \
# 0     Mark P. O. Morford                2002     Oxford University Press
# 1   Richard Bruce Wright                2001       HarperFlamingo Canada
# 2           Carlo D'Este                1991             HarperPerennial
# 3       Gina Bari Kolata                1999        Farrar Straus Giroux
# 4        E. J. W. Barber                1999  W. W. Norton &amp; Company
# ..                   ...                 ...                         ...
# 95    Mary Higgins Clark                1998                      Pocket
# 96       Jennifer Crusie                2001          St. Martin's Press
# 97           Jane Heller                2001          St. Martin's Press
# 98          Michael Rips                2002              Back Bay Books
# 99           Simon Mawer                2002              Back Bay Books
#
#                                           Image-URL-S  \
# 0   http://images.amazon.com/images/P/0195153448.0...
# 1   http://images.amazon.com/images/P/0002005018.0...
# 2   http://images.amazon.com/images/P/0060973129.0...
# 3   http://images.amazon.com/images/P/0374157065.0...
# 4   http://images.amazon.com/images/P/0393045218.0...
# ..                                                ...
# 95  http://images.amazon.com/images/P/0671867156.0...
# 96  http://images.amazon.com/images/P/0312252617.0...
# 97  http://images.amazon.com/images/P/0312261594.0...
# 98  http://images.amazon.com/images/P/0316748641.0...
# 99  http://images.amazon.com/images/P/0316973742.0...
#
#                                           Image-URL-M  \
# 0   http://images.amazon.com/images/P/0195153448.0...
# 1   http://images.amazon.com/images/P/0002005018.0...
# 2   http://images.amazon.com/images/P/0060973129.0...
# 3   http://images.amazon.com/images/P/0374157065.0...
# 4   http://images.amazon.com/images/P/0393045218.0...
# ..                                                ...
# 95  http://images.amazon.com/images/P/0671867156.0...
# 96  http://images.amazon.com/images/P/0312252617.0...
# 97  http://images.amazon.com/images/P/0312261594.0...
# 98  http://images.amazon.com/images/P/0316748641.0...
# 99  http://images.amazon.com/images/P/0316973742.0...
#
#                                           Image-URL-L
# 0   http://images.amazon.com/images/P/0195153448.0...
# 1   http://images.amazon.com/images/P/0002005018.0...
# 2   http://images.amazon.com/images/P/0060973129.0...
# 3   http://images.amazon.com/images/P/0374157065.0...
# 4   http://images.amazon.com/images/P/0393045218.0...
# ..                                                ...
# 95  http://images.amazon.com/images/P/0671867156.0...
# 96  http://images.amazon.com/images/P/0312252617.0...
# 97  http://images.amazon.com/images/P/0312261594.0...
# 98  http://images.amazon.com/images/P/0316748641.0...
# 99  http://images.amazon.com/images/P/0316973742.0...
#
# [100 rows x 8 columns]

# %%
users.head()
# Out:
#    User-ID                            Location   Age
# 0        1                  nyc, new york, usa   NaN
# 1        2           stockton, california, usa  18.0
# 2        3     moscow, yukon territory, russia   NaN
# 3        4           porto, v.n.gaia, portugal  17.0
# 4        5  farnborough, hants, united kingdom   NaN

# %%
ratings.head()
# Out:
#    User-ID        ISBN  Book-Rating
# 0   276725  034545104X            0
# 1   276726  0155061224            5
# 2   276727  0446520802            0
# 3   276729  052165615X            3
# 4   276729  0521795028            6

# %%
print(books.shape)
print(users.shape)
print(ratings.shape)
# Out:
# (271360, 8)
# (278858, 3)
# (1149780, 3)

# %%
books.isnull().sum()
# Out:
# ISBN                   0
# Book-Title             0
# Book-Author            1
# Year-Of-Publication    0
# Publisher              2
# Image-URL-S            0
# Image-URL-M            0
# Image-URL-L            3
# dtype: int64

# %%
users.isnull().sum()
# Out:
# User-ID          0
# Location         0
# Age         110762
# dtype: int64

# %%
ratings.isnull().sum()
# Out:
# User-ID        0
# ISBN           0
# Book-Rating    0
# dtype: int64

# %%
books.duplicated().sum()
# Out:
# 0

# %%
ratings.duplicated().sum()
# Out:
# 0

# %%
users.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## Popularity based recommender system

# %%
ratings_with_name = ratings.merge(books,on='ISBN')

# %%
ratings_with_name
# Out:
#          User-ID        ISBN  Book-Rating  \
# 0         276725  034545104X            0
# 1           2313  034545104X            5
# 2           6543  034545104X            0
# 3           8680  034545104X            5
# 4          10314  034545104X            9
# ...          ...         ...          ...
# 1031131   276688  0517145553            0
# 1031132   276688  1575660792            7
# 1031133   276690  0590907301            0
# 1031134   276704  0679752714            0
# 1031135   276704  0806917695            5
#
#                                                 Book-Title      Book-Author  \
# 0                                     Flesh Tones: A Novel       M. J. Rose
# 1                                     Flesh Tones: A Novel       M. J. Rose
# 2                                     Flesh Tones: A Novel       M. J. Rose
# 3                                     Flesh Tones: A Novel       M. J. Rose
# 4                                     Flesh Tones: A Novel       M. J. Rose
# ...                                                    ...              ...
# 1031131                                    Mostly Harmless    Douglas Adams
# 1031132                                        Gray Matter  Shirley Kennett
# 1031133  Triplet Trouble and the Class Trip (Triplet Tr...     Debbie Dadey
# 1031134  A Desert of Pure Feeling (Vintage Contemporaries)   Judith Freeman
# 1031135  Perplexing Lateral Thinking Puzzles: Scholasti...      Paul Sloane
#
#         Year-Of-Publication                          Publisher  \
# 0                      2002                   Ballantine Books
# 1                      2002                   Ballantine Books
# 2                      2002                   Ballantine Books
# 3                      2002                   Ballantine Books
# 4                      2002                   Ballantine Books
# ...                     ...                                ...
# 1031131                1995             Random House Value Pub
# 1031132                1996  Kensington Publishing Corporation
# 1031133                1997                              Apple
# 1031134                1997                  Vintage Books USA
# 1031135                1997                Sterling Publishing
#
#                                                Image-URL-S  \
# 0        http://images.amazon.com/images/P/034545104X.0...
# 1        http://images.amazon.com/images/P/034545104X.0...
# 2        http://images.amazon.com/images/P/034545104X.0...
# 3        http://images.amazon.com/images/P/034545104X.0...
# 4        http://images.amazon.com/images/P/034545104X.0...
# ...                                                    ...
# 1031131  http://images.amazon.com/images/P/0517145553.0...
# 1031132  http://images.amazon.com/images/P/1575660792.0...
# 1031133  http://images.amazon.com/images/P/0590907301.0...
# 1031134  http://images.amazon.com/images/P/0679752714.0...
# 1031135  http://images.amazon.com/images/P/0806917695.0...
#
#                                                Image-URL-M  \
# 0        http://images.amazon.com/images/P/034545104X.0...
# 1        http://images.amazon.com/images/P/034545104X.0...
# 2        http://images.amazon.com/images/P/034545104X.0...
# 3        http://images.amazon.com/images/P/034545104X.0...
# 4        http://images.amazon.com/images/P/034545104X.0...
# ...                                                    ...
# 1031131  http://images.amazon.com/images/P/0517145553.0...
# 1031132  http://images.amazon.com/images/P/1575660792.0...
# 1031133  http://images.amazon.com/images/P/0590907301.0...
# 1031134  http://images.amazon.com/images/P/0679752714.0...
# 1031135  http://images.amazon.com/images/P/0806917695.0...
#
#                                                Image-URL-L
# 0        http://images.amazon.com/images/P/034545104X.0...
# 1        http://images.amazon.com/images/P/034545104X.0...
# 2        http://images.amazon.com/images/P/034545104X.0...
# 3        http://images.amazon.com/images/P/034545104X.0...
# 4        http://images.amazon.com/images/P/034545104X.0...
# ...                                                    ...
# 1031131  http://images.amazon.com/images/P/0517145553.0...
# 1031132  http://images.amazon.com/images/P/1575660792.0...
# 1031133  http://images.amazon.com/images/P/0590907301.0...
# 1031134  http://images.amazon.com/images/P/0679752714.0...
# 1031135  http://images.amazon.com/images/P/0806917695.0...
#
# [1031136 rows x 10 columns]

# %%
num_rating_df = ratings_with_name.groupby('Book-Title').count()['Book-Rating'].reset_index()
num_rating_df.rename(columns={'Book-Rating':'num_ratings'},inplace=True)
num_rating_df
# Out:
#                                                Book-Title  num_ratings
# 0        A Light in the Storm: The Civil War Diary of ...            4
# 1                                   Always Have Popsicles            1
# 2                    Apple Magic (The Collector's series)            1
# 3        Ask Lily (Young Women of Faith: Lily Series, ...            1
# 4        Beyond IBM: Leadership Marketing and Finance ...            1
# ...                                                   ...          ...
# 241066                                      Ã?Â?lpiraten.            2
# 241067                     Ã?Â?rger mit Produkt X. Roman.            4
# 241068                                Ã?Â?sterlich leben.            1
# 241069                              Ã?Â?stlich der Berge.            3
# 241070                                  Ã?Â?thique en toc            2
#
# [241071 rows x 2 columns]

# %%
avg_rating_df = ratings_with_name.groupby('Book-Title').mean()['Book-Rating'].reset_index()
avg_rating_df.rename(columns={'Book-Rating':'avg_rating'},inplace=True)
avg_rating_df = round(avg_rating_df,3)
avg_rating_df
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_8404\2277834713.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   avg_rating_df = ratings_with_name.groupby('Book-Title').mean()['Book-Rating'].reset_index()
#                                                Book-Title  avg_rating
# 0        A Light in the Storm: The Civil War Diary of ...       2.250
# 1                                   Always Have Popsicles       0.000
# 2                    Apple Magic (The Collector's series)       0.000
# 3        Ask Lily (Young Women of Faith: Lily Series, ...       8.000
# 4        Beyond IBM: Leadership Marketing and Finance ...       0.000
# ...                                                   ...         ...
# 241066                                      Ã?Â?lpiraten.       0.000
# 241067                     Ã?Â?rger mit Produkt X. Roman.       5.250
# 241068                                Ã?Â?sterlich leben.       7.000
# 241069                              Ã?Â?stlich der Berge.       2.667
# 241070                                  Ã?Â?thique en toc       4.000
#
# [241071 rows x 2 columns]

# %%
popular_df = num_rating_df.merge(avg_rating_df,on='Book-Title')
popular_df
# Out:
#                                                Book-Title  num_ratings  \
# 0        A Light in the Storm: The Civil War Diary of ...            4
# 1                                   Always Have Popsicles            1
# 2                    Apple Magic (The Collector's series)            1
# 3        Ask Lily (Young Women of Faith: Lily Series, ...            1
# 4        Beyond IBM: Leadership Marketing and Finance ...            1
# ...                                                   ...          ...
# 241066                                      Ã?Â?lpiraten.            2
# 241067                     Ã?Â?rger mit Produkt X. Roman.            4
# 241068                                Ã?Â?sterlich leben.            1
# 241069                              Ã?Â?stlich der Berge.            3
# 241070                                  Ã?Â?thique en toc            2
#
#         avg_rating
# 0            2.250
# 1            0.000
# 2            0.000
# 3            8.000
# 4            0.000
# ...            ...
# 241066       0.000
# 241067       5.250
# 241068       7.000
# 241069       2.667
# 241070       4.000
#
# [241071 rows x 3 columns]

# %%
popular_df = popular_df[popular_df['num_ratings']>=250].sort_values('avg_rating',ascending=False).head(50)

# %%
popular_df = popular_df.merge(books,on='Book-Title').drop_duplicates('Book-Title')[['Book-Title','num_ratings','avg_rating','Image-URL-M']]

# %%
popular_df
# Out:
#                                             Book-Title  num_ratings  \
# 0    Harry Potter and the Prisoner of Azkaban (Book 3)          428
# 3         Harry Potter and the Goblet of Fire (Book 4)          387
# 5       Harry Potter and the Sorcerer's Stone (Book 1)          278
# 9    Harry Potter and the Order of the Phoenix (Boo...          347
# 13    Harry Potter and the Chamber of Secrets (Book 2)          556
# 16   The Hobbit : The Enchanting Prelude to The Lor...          281
# 17   The Fellowship of the Ring (The Lord of the Ri...          368
# 26   Harry Potter and the Sorcerer's Stone (Harry P...          575
# 28      The Two Towers (The Lord of the Rings, Part 2)          260
# 39                               To Kill a Mockingbird          510
# 47                                   The Da Vinci Code          898
# 53                  The Five People You Meet in Heaven          430
# 55                              The Catcher in the Rye          449
# 62                           The Lovely Bones: A Novel         1295
# 63                                                1984          284
# 72                            Prodigal Summer: A Novel          253
# 73                                          Neverwhere          265
# 78                             The Secret Life of Bees          774
# 84   Stupid White Men ...and Other Sorry Excuses fo...          283
# 85   Tuesdays with Morrie: An Old Man, a Young Man,...          493
# 88                 The Red Tent (Bestselling Backlist)          723
# 89                The Hitchhiker's Guide to the Galaxy          268
# 98    Nickel and Dimed: On (Not) Getting By in America          335
# 100                                      Into the Wild          252
# 103                                     Fahrenheit 451          409
# 116                          Girl with a Pearl Earring          526
# 117                                          Outlander          283
# 123  Where the Heart Is (Oprah's Book Club (Paperba...          585
# 124                     Seabiscuit: An American Legend          275
# 126                                         Life of Pi          664
# 130  A Child Called \It\": One Child's Courage to S...          265
# 132                                     The Bean Trees          389
# 135                                     ANGELA'S ASHES          279
# 137                                        Good in Bed          490
# 139  Fast Food Nation: The Dark Side of the All-Ame...          321
# 140                                      American Gods          302
# 141                                 Skipping Christmas          322
# 147  Left Behind: A Novel of the Earth's Last Days ...          318
# 149    The Golden Compass (His Dark Materials, Book 1)          336
# 157                                   The Color Purple          314
# 163                               Silence of the Lambs          256
# 166                                        About a Boy          262
# 173                  Seven Up (A Stephanie Plum Novel)          278
# 175  The Alchemist: A Fable About Following Your Dream          266
# 177  Hard Eight : A Stephanie Plum Novel (A Stephan...          269
# 182                       Suzanne's Diary for Nicholas          457
# 186                                  Lord of the Flies          259
# 192                            A Prayer for Owen Meany          413
# 194   The Vampire Lestat (Vampire Chronicles, Book II)          301
# 195       White Oleander : A Novel (Oprah's Book Club)          356
#
#      avg_rating                                        Image-URL-M
# 0         5.853  http://images.amazon.com/images/P/0439136350.0...
# 3         5.824  http://images.amazon.com/images/P/0439139597.0...
# 5         5.737  http://images.amazon.com/images/P/0590353403.0...
# 9         5.501  http://images.amazon.com/images/P/043935806X.0...
# 13        5.183  http://images.amazon.com/images/P/0439064872.0...
# 16        5.007  http://images.amazon.com/images/P/0345339681.0...
# 17        4.948  http://images.amazon.com/images/P/0345339703.0...
# 26        4.896  http://images.amazon.com/images/P/059035342X.0...
# 28        4.881  http://images.amazon.com/images/P/0345339711.0...
# 39        4.700  http://images.amazon.com/images/P/0446310786.0...
# 47        4.643  http://images.amazon.com/images/P/0385504209.0...
# 53        4.551  http://images.amazon.com/images/P/0786868716.0...
# 55        4.546  http://images.amazon.com/images/P/0316769487.0...
# 62        4.469  http://images.amazon.com/images/P/0316666343.0...
# 63        4.454  http://images.amazon.com/images/P/0451524934.0...
# 72        4.451  http://images.amazon.com/images/P/0060959037.0...
# 73        4.449  http://images.amazon.com/images/P/0380789019.0...
# 78        4.447  http://images.amazon.com/images/P/0142001740.0...
# 84        4.357  http://images.amazon.com/images/P/0060392452.0...
# 85        4.355  http://images.amazon.com/images/P/0385484518.0...
# 88        4.335  http://images.amazon.com/images/P/0312195516.0...
# 89        4.328  http://images.amazon.com/images/P/0671461494.0...
# 98        4.290  http://images.amazon.com/images/P/0805063897.0...
# 100       4.274  http://images.amazon.com/images/P/0385486804.0...
# 103       4.264  http://images.amazon.com/images/P/3257208626.0...
# 116       4.219  http://images.amazon.com/images/P/0452282152.0...
# 117       4.173  http://images.amazon.com/images/P/0440222915.0...
# 123       4.106  http://images.amazon.com/images/P/0446672211.0...
# 124       4.098  http://images.amazon.com/images/P/0449005615.0...
# 126       4.089  http://images.amazon.com/images/P/0151008116.0...
# 130       4.087  http://images.amazon.com/images/P/1558743669.0...
# 132       4.087  http://images.amazon.com/images/P/0060915544.0...
# 135       4.075  http://images.amazon.com/images/P/0684874350.0...
# 137       4.055  http://images.amazon.com/images/P/0743418174.0...
# 139       4.037  http://images.amazon.com/images/P/0060938455.0...
# 140       4.007  http://images.amazon.com/images/P/0380789035.0...
# 141       4.006  http://images.amazon.com/images/P/0385505833.0...
# 147       4.003  http://images.amazon.com/images/P/0842329129.0...
# 149       4.000  http://images.amazon.com/images/P/037582345X.0...
# 157       3.965  http://images.amazon.com/images/P/0671617028.0...
# 163       3.961  http://images.amazon.com/images/P/0312924585.0...
# 166       3.901  http://images.amazon.com/images/P/1573227331.0...
# 173       3.888  http://images.amazon.com/images/P/0312265840.0...
# 175       3.876  http://images.amazon.com/images/P/0062502174.0...
# 177       3.825  http://images.amazon.com/images/P/0312983867.0...
# 182       3.821  http://images.amazon.com/images/P/0316969443.0...
# 186       3.819  http://images.amazon.com/images/P/0399501487.0...
# 192       3.797  http://images.amazon.com/images/P/0345361792.0...
# 194       3.777  http://images.amazon.com/images/P/0345313860.0...
# 195       3.772  http://images.amazon.com/images/P/0316284955.0...

# %% [markdown]
# ## collaborative filtering based recommendation system

# %%
x = ratings_with_name.groupby('User-ID').count()['Book-Rating'] > 200
rated_users = x[x].index

# %%
filtered_rating = ratings_with_name[ratings_with_name['User-ID'].isin(rated_users)]

# %%
y = filtered_rating.groupby('Book-Title').count()['Book-Rating'] >= 50
rated_books = y[y].index

# %%
final_ratings = filtered_rating[filtered_rating['Book-Title'].isin(rated_books)]

# %%
final = final_ratings.pivot_table(index='Book-Title',columns='User-ID',values='Book-Rating')

# %%
final.fillna(0,inplace=True)

# %%
final
# Out:
# User-ID                                             254     2276    2766    \
# Book-Title
# 1984                                                   9.0     0.0     0.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2nd Chance                                             0.0    10.0     0.0
# 4 Blondes                                              0.0     0.0     0.0
# A Bend in the Road                                     0.0     0.0     7.0
# ...                                                    ...     ...     ...
# Year of Wonders                                        0.0     0.0     0.0
# You Belong To Me                                       0.0     0.0     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0     0.0     0.0
# Zoya                                                   0.0     0.0     0.0
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
#
# User-ID                                             2977    3363    4017    \
# Book-Title
# 1984                                                   0.0     0.0     0.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2nd Chance                                             0.0     0.0     0.0
# 4 Blondes                                              0.0     0.0     0.0
# A Bend in the Road                                     0.0     0.0     0.0
# ...                                                    ...     ...     ...
# Year of Wonders                                        7.0     0.0     0.0
# You Belong To Me                                       0.0     0.0     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0     0.0     0.0
# Zoya                                                   0.0     0.0     0.0
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
#
# User-ID                                             4385    6251    6323    \
# Book-Title
# 1984                                                   0.0     0.0     0.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2nd Chance                                             0.0     0.0     0.0
# 4 Blondes                                              0.0     0.0     0.0
# A Bend in the Road                                     0.0     0.0     0.0
# ...                                                    ...     ...     ...
# Year of Wonders                                        0.0     0.0     0.0
# You Belong To Me                                       0.0     0.0     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0     0.0     0.0
# Zoya                                                   0.0     0.0     0.0
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
#
# User-ID                                             6543    ...  271705  \
# Book-Title                                                  ...
# 1984                                                   0.0  ...    10.0
# 1st to Die: A Novel                                    9.0  ...     0.0
# 2nd Chance                                             0.0  ...     0.0
# 4 Blondes                                              0.0  ...     0.0
# A Bend in the Road                                     0.0  ...     0.0
# ...                                                    ...  ...     ...
# Year of Wonders                                        0.0  ...     0.0
# You Belong To Me                                       0.0  ...     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0  ...     0.0
# Zoya                                                   0.0  ...     0.0
# \O\" Is for Outlaw"                                    0.0  ...     0.0
#
# User-ID                                             273979  274004  274061  \
# Book-Title
# 1984                                                   0.0     0.0     0.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2nd Chance                                             0.0     0.0     0.0
# 4 Blondes                                              0.0     0.0     0.0
# A Bend in the Road                                     0.0     0.0     0.0
# ...                                                    ...     ...     ...
# Year of Wonders                                        9.0     0.0     0.0
# You Belong To Me                                       0.0     0.0     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0     0.0     0.0
# Zoya                                                   0.0     0.0     0.0
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
#
# User-ID                                             274301  274308  275970  \
# Book-Title
# 1984                                                   0.0     0.0     0.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2nd Chance                                             0.0     0.0     0.0
# 4 Blondes                                              0.0     0.0     0.0
# A Bend in the Road                                     0.0     0.0     0.0
# ...                                                    ...     ...     ...
# Year of Wonders                                        0.0     0.0     0.0
# You Belong To Me                                       0.0     0.0     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0     0.0     0.0
# Zoya                                                   0.0     0.0     0.0
# \O\" Is for Outlaw"                                    8.0     0.0     0.0
#
# User-ID                                             277427  277639  278418
# Book-Title
# 1984                                                   0.0     0.0     0.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2nd Chance                                             0.0     0.0     0.0
# 4 Blondes                                              0.0     0.0     0.0
# A Bend in the Road                                     0.0     0.0     0.0
# ...                                                    ...     ...     ...
# Year of Wonders                                        0.0     0.0     0.0
# You Belong To Me                                       0.0     0.0     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0     0.0     0.0
# Zoya                                                   0.0     0.0     0.0
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
#
# [706 rows x 810 columns]

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
similarity_score = cosine_similarity(final)

# %%
similarity_score
# Out:
# array([[1.        , 0.10255025, 0.01220856, ..., 0.12110367, 0.07347567,
#         0.04316046],
#        [0.10255025, 1.        , 0.2364573 , ..., 0.07446129, 0.16773875,
#         0.14263397],
#        [0.01220856, 0.2364573 , 1.        , ..., 0.04558758, 0.04938579,
#         0.10796119],
#        ...,
#        [0.12110367, 0.07446129, 0.04558758, ..., 1.        , 0.07085128,
#         0.0196177 ],
#        [0.07347567, 0.16773875, 0.04938579, ..., 0.07085128, 1.        ,
#         0.10602962],
#        [0.04316046, 0.14263397, 0.10796119, ..., 0.0196177 , 0.10602962,
#         1.        ]])

# %%
similarity_score.shape
# Out:
# (706, 706)

# %%
def recommend(book_name):
    #index fetch
    index = np.where(final.index==book_name)[0][0]
    similar_items = sorted(list(enumerate(similarity_score[index])),key=lambda x:x[1],reverse=True)[1:6]
    data = []
    for i in similar_items:
        item = []
        temp_df = books[books['Book-Title'] == final.index[i[0]]]
        item.extend(list(temp_df.drop_duplicates('Book-Title')['Book-Title'].values))
        item.extend(list(temp_df.drop_duplicates('Book-Title')['Book-Author'].values))
        item.extend(list(temp_df.drop_duplicates('Book-Title')['Image-URL-M'].values))
        
        data.append(item)
        
    return data

# %%
recommend('1984')
# Out:
# [['Animal Farm',
#   'George Orwell',
#   'http://images.amazon.com/images/P/0451526341.01.MZZZZZZZ.jpg'],
#  ["The Handmaid's Tale",
#   'Margaret Atwood',
#   'http://images.amazon.com/images/P/0449212602.01.MZZZZZZZ.jpg'],
#  ['Brave New World',
#   'Aldous Huxley',
#   'http://images.amazon.com/images/P/0060809833.01.MZZZZZZZ.jpg'],
#  ['The Vampire Lestat (Vampire Chronicles, Book II)',
#   'ANNE RICE',
#   'http://images.amazon.com/images/P/0345313860.01.MZZZZZZZ.jpg'],
#  ['The Hours : A Novel',
#   'Michael Cunningham',
#   'http://images.amazon.com/images/P/0312243022.01.MZZZZZZZ.jpg']]

# %%
recommend('Message in a Bottle')
# Out:
# [['Nights in Rodanthe',
#   'Nicholas Sparks',
#   'http://images.amazon.com/images/P/0446531332.01.MZZZZZZZ.jpg'],
#  ['The Mulberry Tree',
#   'Jude Deveraux',
#   'http://images.amazon.com/images/P/0743437640.01.MZZZZZZZ.jpg'],
#  ['A Walk to Remember',
#   'Nicholas Sparks',
#   'http://images.amazon.com/images/P/0446608955.01.MZZZZZZZ.jpg'],
#  ["River's End",
#   'Nora Roberts',
#   'http://images.amazon.com/images/P/0515127833.01.MZZZZZZZ.jpg'],
#  ['Nightmares &amp; Dreamscapes',
#   'Stephen King',
#   'http://images.amazon.com/images/P/0451180232.01.MZZZZZZZ.jpg']]

# %%
recommend('The Notebook')
# Out:
# [['A Walk to Remember',
#   'Nicholas Sparks',
#   'http://images.amazon.com/images/P/0446608955.01.MZZZZZZZ.jpg'],
#  ['The Rescue',
#   'Nicholas Sparks',
#   'http://images.amazon.com/images/P/0446610399.01.MZZZZZZZ.jpg'],
#  ['One Door Away from Heaven',
#   'Dean R. Koontz',
#   'http://images.amazon.com/images/P/0553582755.01.MZZZZZZZ.jpg'],
#  ['Toxin',
#   'Robin Cook',
#   'http://images.amazon.com/images/P/0425166619.01.MZZZZZZZ.jpg'],
#  ['The Five People You Meet in Heaven',
#   'Mitch Albom',
#   'http://images.amazon.com/images/P/0786868716.01.MZZZZZZZ.jpg']]

# %%
recommend('A Bend in the Road')
# Out:
# [['A Walk to Remember',
#   'Nicholas Sparks',
#   'http://images.amazon.com/images/P/0446608955.01.MZZZZZZZ.jpg'],
#  ['The Last Time They Met : A Novel',
#   'Anita Shreve',
#   'http://images.amazon.com/images/P/0316781266.01.MZZZZZZZ.jpg'],
#  ['Sea Glass: A Novel',
#   'Anita Shreve',
#   'http://images.amazon.com/images/P/0316089699.01.MZZZZZZZ.jpg'],
#  ['Angels',
#   'Marian Keyes',
#   'http://images.amazon.com/images/P/0060008024.01.MZZZZZZZ.jpg'],
#  ['Family Album',
#   'Danielle Steel',
#   'http://images.amazon.com/images/P/0440124344.01.MZZZZZZZ.jpg']]

# %%
recommend('Zoya')
# Out:
# [['Fine Things',
#   'Danielle Steel',
#   'http://images.amazon.com/images/P/0440200563.01.MZZZZZZZ.jpg'],
#  ['Secrets',
#   'DANIELLE STEEL',
#   'http://images.amazon.com/images/P/0440176484.01.MZZZZZZZ.jpg'],
#  ['Kaleidoscope',
#   'June Stepansky',
#   'http://images.amazon.com/images/P/0884092097.01.MZZZZZZZ.jpg'],
#  ['Exclusive',
#   'Sandra Brown',
#   'http://images.amazon.com/images/P/0446604232.01.MZZZZZZZ.jpg'],
#  ['Five Days in Paris',
#   'DANIELLE STEEL',
#   'http://images.amazon.com/images/P/0440222842.01.MZZZZZZZ.jpg']]

# %%
import pickle
pickle.dump(popular_df,open('popular.pkl','wb'))

# %%
pickle.dump(final,open('final.pkl','wb'))
pickle.dump(books,open('books.pkl','wb'))
pickle.dump(similarity_score,open('similarity_score.pkl','wb'))
